# %% [markdown]
#  <table><tr><td><img src="images/dbmi_logo.png" width="75" height="73" alt="Pitt Biomedical Informatics logo"></td><td><img src="images/pitt_logo.png" width="75" height="75" alt="University of Pittsburgh logo"></td></tr></table>
#
#
# # Social Media and Data Science - Part 2
#
# Data science modules developed by the University of Pittsburgh Biomedical Informatics Training Program with the support of the National Library of Medicine data science supplement to the University of Pittsburgh (Grant # T15LM007059-30S1).
#
# Developed by Harry Hochheiser, harryh@pitt.edu. All errors are my responsibility.
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %% [markdown]
# ###  *Goal*: Use social media posts to explore the appplication of text and natural language processing to see what might be learned from online interactions.
#
# Specifically, we will retrieve, annotate, process, and interpret Twitter data on health-related issues such as depression.

# %% [markdown]
# ---
# References:
# * [Mining Twitter Data with Python (Part 1: Collecting data)](https://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/)
# * The [Tweepy Python API for Twitter](http://www.tweepy.org/)
# ---

# %%
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import jsonpickle
import json
import random
import tweepy
import time
import operator
from datetime import datetime

# %% [markdown]
# ## 2.0.1 Setup
#
# Before we dig in, we must grab a bit of code from [Part 1](SocialMedia%20-%20Part%201.ipynb):
#
# 1. The Tweets class used to store the tweets.
# 2. Our twitter API Keys - be sure to copy the keys that you generated when you completed [Part 1](SocialMedia%20-%20Part%201.ipynb).
# 3. Configuration of our Twitter connection

# %%
class Tweets:
    
    
    def __init__(self,term="",corpus_size=100):
        self.tweets={}
        if term !="":
            self.searchTwitter(term,corpus_size)
    
    def searchTwitter(self,term,corpus_size):
        searchTime=datetime.now()
        while (self.countTweets() < corpus_size):
            new_tweets = api.search(term,lang="en",tweet_mode='extended',count=corpus_size)
            for nt_json in new_tweets:
                nt = nt_json._json
                if self.getTweet(nt['id_str']) is None and self.countTweets() < corpus_size:
                    self.addTweet(nt,searchTime,term)
            time.sleep(120)
                
    def addTweet(self,tweet,searchTime,term="",count=0):
        id = tweet['id_str']
        if id not in self.tweets.keys():
            self.tweets[id]={}
            self.tweets[id]['tweet']=tweet
            self.tweets[id]['count']=0
            self.tweets[id]['searchTime']=searchTime
            self.tweets[id]['searchTerm']=term
        self.tweets[id]['count'] = self.tweets[id]['count'] +1
        
    def combineTweets(self,other):
        for otherid in other.getIds():
            tweet = other.getTweet(otherid)
            searchTerm = other.getSearchTerm(otherid)
            searchTime = other.getSearchTime(otherid)
            self.addTweet(tweet,searchTime,searchTerm)
        
    def getTweet(self,id):
        if id in self.tweets:
            return self.tweets[id]['tweet']
        else:
            return None
    
    def getTweetCount(self,id):
        return self.tweets[id]['count']
    
    def countTweets(self):
        return len(self.tweets)
    
    # return a sorted list of tupes of the form (id,count), with the occurrence counts sorted in decreasing order
    def mostFrequent(self):
        ps = []
        for t,entry in self.tweets.items():
            count = entry['count']
            ps.append((t,count))  
        ps.sort(key=lambda x: x[1],reverse=True)
        return ps
    
    # reeturns tweet IDs as a set
    def getIds(self):
        return set(self.tweets.keys())
    
    # save the tweets to a file
    def saveTweets(self,filename):
        json_data =jsonpickle.encode(self.tweets)
        with open(filename,'w') as f:
            json.dump(json_data,f)
    
    # read the tweets from a file 
    def readTweets(self,filename):
        with open(filename,'r') as f:
            json_data = json.load(f)
            incontents = jsonpickle.decode(json_data)   
            self.tweets=incontents
        
    def getSearchTerm(self,id):
        return self.tweets[id]['searchTerm']
    
    def getSearchTime(self,id):
        return self.tweets[id]['searchTime']
    
    def getText(self,id):
        tweet = self.getTweet(id)
        text=tweet['full_text']
        if 'retweeted_status'in tweet:
            original = tweet['retweeted_status']
            text=original['full_text']
        return text

# %% [markdown]
# Put the values of your keys into these variables

# %%
consumer_key = 'a5FolotxJtSGFgGbTRYV4WTc1'
consumer_secret = 'ne5nZE4ksr8jWeW2qurUxkAVHiVNy2cjUfsRR2AzxExEdbkXRK'
access_token = '285748486-K9yLW99tB8KqSkBlmc50qfHvKhAolAts4FSj22Qw'
access_secret = 'ub5iVbOl24PXaKEYzeMsBoegwYQXL9P5iQ12cyDGB780g'

# %%
from tweepy import OAuthHandler

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %% [markdown]
# ## 2.1 Annotating Tweets

# %% [markdown]
# Now that we have a corpus of tweets, what do we want to do with them? Turning a relatively vague notion into a well-defined research question is often a significant challenge, as examination of the data often reveals both shortcomings and unforeseen opportunities.
#
# In our case, we are interested in looking at tweets about smoking, but we're not quite sure exactly *what* we are looking for. We have a vague notion that we might learn something interesting, but understanding exactly what that is, and what sort of analyses we might need, will require a bit more work.
#
# In situations such as this, we might look at some of the data to form some preliminary impressions of the content. Specifically, we can look at indidividual tweets, assigning them to one or more categories - known as *codes* - based on their content.  We can add categories as needed to capture important ideas that we might want to refer back to. This practice - known as *open coding* allows us to begin to make sense of unfamiliar data sets.
#
# This sounds much more complicated than it is. For now, let's start with some of the data that you used  in [Part 1](SocialMedia%20-%20Part%201.ipynb). If you completed this exercise, you should have 100 tweets associated with the search term 'smoking' in a file names `tweets.json`. If you didn't complete this exercise, please go back and do so.

# %%
tweets =Tweets()
tweets.readTweets("tweets.json")

# %% [markdown]
# We check the count, to verify the contents...

# %%
print(tweets.countTweets())
# Out:
# 100

# %% [markdown]
# We will begin by taking a look at a subset of the first 20 tweets
#
# To get this list, we'll sort the ids of the tweets and take the first 10 in the list, as ordered by ID

# %%
ids=list(tweets.getIds())
ids.sort()
working=[]
for i in range(20):
    id = ids[i]
    working.append(id)

# %% [markdown]
# *working* now has 20 tweets ids. Let's start with the first.

# %%
td = working[0]
print(tweets.getSearchTerm(id))
print(tweets.getSearchTime(id))
print(tweets.getText(td))
# Out:
# smoking
# 2019-10-26 16:47:35.335256
# Guys, when you're drunk, do you also fry Potato chips in the Microwave or I should just stop smoking weed? https://t.co/X53daAcx9a

# %% [markdown]
# This tweet might have any of several interesting characteristics. It might be a retweet; it might specifically mention marijunana or tobacco; or it might not be related to either of these.
#
# We can model any and all of these points through relevant annotation. Specifically, we will a new array of codes to each tweet object. This array will contain a list of categorical annotations associated with the tweet.  We add routines to add a single code to a tweet (by ID), to add multiple codes, and to retrieve the list of codes associated with a tweet.
#
#
# See modifications to the  Tweets object in this new definition.

# %%
class Tweets:
    
    
    def __init__(self,term="",corpus_size=100):
        self.tweets={}
        if term !="":
            self.searchTwitter(term,corpus_size)
                
    def searchTwitter(self,term,corpus_size):
        searchTime=datetime.now()
        while (self.countTweets() < corpus_size):
            new_tweets = api.search(term,lang="en",tweet_mode='extended',count=corpus_size)
            for nt_json in new_tweets:
                nt = nt_json._json
                if self.getTweet(nt['id_str']) is None and self.countTweets() < corpus_size:
                    self.addTweet(nt,searchTime,term)
            time.sleep(120)
                
    def addTweet(self,tweet,searchTime,term="",count=0):
        id = tweet['id_str']
        if id not in self.tweets.keys():
            self.tweets[id]={}
            self.tweets[id]['tweet']=tweet
            self.tweets[id]['count']=0
            self.tweets[id]['searchTime']=searchTime
            self.tweets[id]['searchTerm']=term
        self.tweets[id]['count'] = self.tweets[id]['count'] +1

    def combineTweets(self,other):
        for otherid in other.getIds():
            tweet = other.getTweet(otherid)
            searchTerm = other.getSearchTerm(otherid)
            searchTime = other.getSearchTime(otherid)
            self.addTweet(tweet,searchTime,searchTerm)
        
    def getTweet(self,id):
        if id in self.tweets:
            return self.tweets[id]['tweet']
        else:
            return None
    
    def getTweetCount(self,id):
        return self.tweets[id]['count']
    
    def countTweets(self):
        return len(self.tweets)
    
    # return a sorted list of tupes of the form (id,count), with the occurrence counts sorted in decreasing order
    def mostFrequent(self):
        ps = []
        for t,entry in self.tweets.items():
            count = entry['count']
            ps.append((t,count))  
        ps.sort(key=lambda x: x[1],reverse=True)
        return ps
    
    # reeturns tweet IDs as a set
    def getIds(self):
        return set(self.tweets.keys())
    
    # save the tweets to a file
    def saveTweets(self,filename):
        json_data =jsonpickle.encode(self.tweets)
        with open(filename,'w') as f:
            json.dump(json_data,f)
    
    # read the tweets from a file 
    def readTweets(self,filename):
        with open(filename,'r') as f:
            json_data = json.load(f)
            incontents = jsonpickle.decode(json_data)   
            self.tweets=incontents
        
    def getSearchTerm(self,id):
        return self.tweets[id]['searchTerm']
    
    def getSearchTime(self,id):
        return self.tweets[id]['searchTime']
    
    def getText(self,id):
        tweet = self.getTweet(id)
        text=tweet['full_text']
        if 'retweeted_status'in tweet:
            original = tweet['retweeted_status']
            text=original['full_text']
        return text
                
    ### NEW ROUTINE - add a code to a tweet
    def addCode(self,id,code):
        tweet=self.getTweet(id)
        if 'codes' not in tweet:
            tweet['codes']=set()
        tweet['codes'].add(code)
        
    ### NEW ROUTINE  - add multiple  codes for a tweet
    def addCodes(self,id,codes):
        for code in codes:
            self.addCode(id,code)
        
    ### NEW ROUTINE get codes for a tweet
    def getCodes(self,id):
        tweet=self.getTweet(id)
        if 'codes' in tweet:
            return tweet['codes']
        else:
            return None
        
    def countCodes(self):
        codesList = {}
        for id in tweets.getIds():
            # get list of codes 
            if tweets.getCodes(id)is not None:
                codes = list(tweets.getCodes(id))
                if len(codes) > 0:
                    for code in codes:
                        #if its not in the list of codes put 0 occurances
                        if code not in codesList:
                            codesList[code] = 0
                        # if code found add occurance to count 
                        codesList[code] = codesList[code] + 1
        #return list sorted 
        return  sorted(codesList.items(), key=lambda kv: kv[1], reverse = True)

# %% [markdown]
# Now that we have this set up, we can load tweets from a file and reload the subset.
#
# Note that thsis file is not acutally real tweets - it's just fabricated tweets that have been put together for purposes of this lesson. The text, user name, and other details are all wrong or omitted.  Later, you'll try this with the tweets you loaded in your search.

# %%
tweets =Tweets()
tweets.readTweets("tweets-fake.json")
ids=list(tweets.getIds())
ids.sort()
working=[]

for i in range(len(ids)):
    id = ids[i]
    working.append(id)

td = working[0]
t = tweets.getTweet(td)
tweets.getText(td)
# Out:
# 'Need some 420. #weed'

# %% [markdown]
# so, this tweet seems to be about marijuana. We can add a code to this effect.

# %%
tweets.addCode(td,"MARIJUANA")

# %% [markdown]
# We can also confirm that this tweet is associated with the desired codes:

# %%
tweets.getCodes(td)
# Out:
# {'MARIJUANA'}

# %% [markdown]
# Good. Let's look at the next tweet.

# %%
td = working[1]
tweets.getText(td)
# Out:
# 'Too funny - what have you been smoking..?'

# %% [markdown]
# This tweet contains a generic mention of smoking, without much detail, but we might gues that it is also about marijuana

# %%
tweets.addCodes(td,['MARIJUANA'])

# %% [markdown]
# ok.. moving on to the third tweet..

# %%
td = working[2]
tweets.getText(td)
# Out:
# 'Three weeks off of smoking cigarettes. #feelingood'

# %%
tweets.addCodes(td,['QUITTING','BENEFITS'])

# %% [markdown]
# next...

# %%
td = working[3]
tweets.getText(td)
# Out:
# 'FDA begins anti-smoking efforts https://www.fda.gov @fda'

# %% [markdown]
# This note mentions government quitting efforts, and has both a link and a user mention.

# %%
tweets.addCodes(td,['LINK','USERMENTION','GOVERNMENT','QUITTING'])

# %%
td = working[4]
tweets.getText(td)
# Out:
# 'Juul is cool. Not.'

# %% [markdown]
# This tweet mentions a negatigve attitude towards vaping.

# %%
tweets.addCodes(td,['VAPING','NEGATIVE'])

# %% [markdown]
# Now that we've gone through several tweets, we can review the codes used.

# %%
for i in range(5):
    td=working[i]
    print(tweets.getCodes(td))
# Out:
# {'MARIJUANA'}
# {'MARIJUANA'}
# {'BENEFITS', 'QUITTING'}
# {'GOVERNMENT', 'LINK', 'QUITTING', 'USERMENTION'}
# {'VAPING', 'NEGATIVE'}

# %% [markdown]
# Having annotated several tweets, we might want to save the annotations in a file for future use. Fortnuately, the approach that we've used in our save and reload code is flexible enough to handle this without any further changes to the implementation.
#
# How does this work? The `Tweets` class stores all of the information abou the tweets in a simple dictionary. Tweet counts and codes are then stored inside the tweet object. When we go to save the set of Tweets, we simply turn this dictionary into JSON and then write it to a file. To read things in, we just read the JSON from the file and convert the result back into a dictionary. Thus, anything that we add to the dictionary will automatically be writen out and read back in.  We still need additional routines to access this data (like `addCode`, `addCodes`, and `getCodes`), but we  don't need to change the save/load routines.  Let's try it out.

# %%
tweets.saveTweets("tweets-fake-annotated.json")

# %%
tweets2=Tweets()
tweets2.readTweets("tweets-fake-annotated.json")

# %%
print(tweets.getText(td))
print(tweets.getCodes(td))
print(tweets2.getText(td))
print(tweets2.getCodes(td))
# Out:
# Juul is cool. Not.
# {'VAPING', 'NEGATIVE'}
# Juul is cool. Not.
# {'VAPING', 'NEGATIVE'}

# %%
tweets.countCodes()
# Out:
# [('MARIJUANA', 2),
#  ('QUITTING', 2),
#  ('VAPING', 1),
#  ('NEGATIVE', 1),
#  ('GOVERNMENT', 1),
#  ('LINK', 1),
#  ('USERMENTION', 1),
#  ('BENEFITS', 1)]

# %% [markdown]
# ****
# # Exercise 2.1: Examining the distribution of codes across a corpus
#
# Having annotated a number of tweets, you might want to get an idea of how many tweets are being used and how often. Write a new method inside the `Tweets` class to provide a list of codes and counts, sorted by frequency.  Please be sure to reload the tweets after you redefine the class.
#
# *ANSWER FOLLOWS - insert here*

# %%
ini_list = [1, 1, 2, 2, 2, 3, 3, 3, 3, 3, 
               5, 5, 5, 4, 4, 4, 4, 4, 4] 

# printing initial ini_list 
print ("initial list", str(ini_list)) 
  
# sorting on bais of frequency of elements 
result = sorted(ini_list, key = ini_list.count, 
                                reverse = True) 
  
# printing final result 
print("final list", str(result))
# Out:
# initial list [1, 1, 2, 2, 2, 3, 3, 3, 3, 3, 5, 5, 5, 4, 4, 4, 4, 4, 4]
# final list [4, 4, 4, 4, 4, 4, 3, 3, 3, 3, 3, 2, 2, 2, 5, 5, 5, 1, 1]

# %%
def countCodes(self):
        # create empty code list 
        codesList = {}
        for id in tweets.getIds():
            # get list of codes
            if tweets.getCodes(id)is not None:
                codes = list(tweets.getCodes(id))
                if len(codes) > 0:
                    for code in codes:
                        #if code not in the list of codes from the tweets put 0 occurances
                        if code not in codesList:
                            codesList[code] = 0
                        # if code found add occurance to count 
                        codesList[code] = codesList[code] + 1
        #r eturn list sorted by frequency 
        return  sorted(codesList.items(), key=lambda kv: kv[1], reverse = True)

# %% [markdown]
# *END CUT HERE*
# ****

# %% [markdown]
# # Exercise 2.2: Code the Next 10 tweets in the set.
# Start with the tags used above, adding your own as needed.  Code up to and including the tweet  with index 20 in the `working` array. Examine the code profile and save your tweets  to a new file when you are done.

# %% [markdown]
# *ANSWER FOLLOWS - insert here*

# %%
top_twenty = []
i =0
for tweet in tweepy.Cursor(api.home_timeline,tweet_mode='extended').items(100):
    top_twenty.append(tweet._json)

# %%
top_twenty
# Out:
# [{'created_at': 'Tue Oct 29 00:22:56 +0000 2019',
#   'id': 1188974464089767936,
#   'id_str': '1188974464089767936',
#   'full_text': 'RT @delafuenteupenn: Public speaking is hard, particularly for non-native speakers. I highly recommend attending this! https://t.co/CZqAOaN…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'delafuenteupenn',
#      'name': 'César de la Fuente',
#      'id': 3011656064,
#      'id_str': '3011656064',
#      'indices': [3, 19]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 903904045,
#    'id_str': '903904045',
#    'name': 'Arnaldo Díaz Vázquez, PhD',
#    'screen_name': 'ADiaz_PhD',
#    'location': 'Philadelphia, PA',
#    'description': 'Asst Dean @PennMedicine | Dir. @ORDTUPenn | Adj Asst Prof @PennSysPharmATT | #Diversity #Inclusion & #FirstGen Advocate | @uprrp & @TAMU alumnus |🇵🇷|Views=Own',
#    'url': 'https://t.co/88QRrQroVj',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/88QRrQroVj',
#        'expanded_url': 'https://www.med.upenn.edu/pharm/index.shtml',
#        'display_url': 'med.upenn.edu/pharm/index.sh…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4516,
#    'friends_count': 4506,
#    'listed_count': 33,
#    'created_at': 'Thu Oct 25 13:21:42 +0000 2012',
#    'favourites_count': 13473,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 9935,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1180548378121424896/BRCoShqi_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1180548378121424896/BRCoShqi_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/903904045/1523357574',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 29 00:12:37 +0000 2019',
#    'id': 1188971866494509057,
#    'id_str': '1188971866494509057',
#    'full_text': 'Public speaking is hard, particularly for non-native speakers. I highly recommend attending this! https://t.co/CZqAOaN9hH',
#    'truncated': False,
#    'display_text_range': [0, 97],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/CZqAOaN9hH',
#       'expanded_url': 'https://twitter.com/Penn_SACNAS/status/1188960493039509504',
#       'display_url': 'twitter.com/Penn_SACNAS/st…',
#       'indices': [98, 121]}]},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3011656064,
#     'id_str': '3011656064',
#     'name': 'César de la Fuente',
#     'screen_name': 'delafuenteupenn',
#     'location': 'Philadelphia, PA',
#     'description': 'Presidential Assistant Professor at the University of Pennsylvania.',
#     'url': 'https://t.co/MAxgQmSEP6',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/MAxgQmSEP6',
#         'expanded_url': 'https://delafuentelab.seas.upenn.edu/',
#         'display_url': 'delafuentelab.seas.upenn.edu',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1351,
#     'friends_count': 269,
#     'listed_count': 18,
#     'created_at': 'Fri Feb 06 20:17:01 +0000 2015',
#     'favourites_count': 1430,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1087,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/788399680287834112/eBELzSMn_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/788399680287834112/eBELzSMn_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3011656064/1535643185',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1188960493039509504,
#    'quoted_status_id_str': '1188960493039509504',
#    'quoted_status_permalink': {'url': 'https://t.co/CZqAOaN9hH',
#     'expanded': 'https://twitter.com/Penn_SACNAS/status/1188960493039509504',
#     'display': 'twitter.com/Penn_SACNAS/st…'},
#    'quoted_status': {'created_at': 'Mon Oct 28 23:27:26 +0000 2019',
#     'id': 1188960493039509504,
#     'id_str': '1188960493039509504',
#     'full_text': 'Join us on Monday, Nov 4, for the 2nd part of our seminars on public speaking! This time we’ll have Lindsay Roth (@lroth8626), Chair of @UPennBGSA, and a student panel giving advice on how to best prepare a poster presentation. Come to enhance this crucial skill for scientists! https://t.co/OtDl3P0TG2',
#     'truncated': False,
#     'display_text_range': [0, 278],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'lroth8626',
#        'name': 'Lindsay Roth',
#        'id': 735104517012783104,
#        'id_str': '735104517012783104',
#        'indices': [114, 124]},
#       {'screen_name': 'UPennBGSA',
#        'name': 'UPenn BGSA',
#        'id': 343596470,
#        'id_str': '343596470',
#        'indices': [136, 146]}],
#      'urls': [],
#      'media': [{'id': 1188960488002072576,
#        'id_str': '1188960488002072576',
#        'indices': [279, 302],
#        'media_url': 'http://pbs.twimg.com/media/EIAJQ7NWsAAqVPK.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EIAJQ7NWsAAqVPK.jpg',
#        'url': 'https://t.co/OtDl3P0TG2',
#        'display_url': 'pic.twitter.com/OtDl3P0TG2',
#        'expanded_url': 'https://twitter.com/Penn_SACNAS/status/1188960493039509504/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 816, 'h': 1056, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 816, 'h': 1056, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1188960488002072576,
#        'id_str': '1188960488002072576',
#        'indices': [279, 302],
#        'media_url': 'http://pbs.twimg.com/media/EIAJQ7NWsAAqVPK.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EIAJQ7NWsAAqVPK.jpg',
#        'url': 'https://t.co/OtDl3P0TG2',
#        'display_url': 'pic.twitter.com/OtDl3P0TG2',
#        'expanded_url': 'https://twitter.com/Penn_SACNAS/status/1188960493039509504/photo/1',
#        'type': 'photo',
#        'sizes': {'medium': {'w': 816, 'h': 1056, 'resize': 'fit'},
#         'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 525, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 816, 'h': 1056, 'resize': 'fit'}}}]},
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'in_reply_to_screen_name': None,
#     'user': {'id': 769921313137754112,
#      'id_str': '769921313137754112',
#      'name': 'Penn SACNAS',
#      'screen_name': 'Penn_SACNAS',
#      'location': 'Philadelphia, PA',
#      'description': 'Penn @sacnas chapter aims to promote underrepresented minorities with advanced degrees in STEM and to provide educational and professional opportunities.',
#      'url': 'https://t.co/ABl37cJKcX',
#      'entities': {'url': {'urls': [{'url': 'https://t.co/ABl37cJKcX',
#          'expanded_url': 'http://www.med.upenn.edu/sacnas/',
#          'display_url': 'med.upenn.edu/sacnas/',
#          'indices': [0, 23]}]},
#       'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 853,
#      'friends_count': 753,
#      'listed_count': 24,
#      'created_at': 'Sun Aug 28 15:35:20 +0000 2016',
#      'favourites_count': 5389,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 3449,
#      'lang': None,
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1136359583562194944/-dPX5UBB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1136359583562194944/-dPX5UBB_normal.jpg',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/769921313137754112/1472398711',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'has_extended_profile': False,
#      'default_profile': True,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 0,
#     'favorite_count': 1,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'possibly_sensitive_appealable': False,
#     'lang': 'en'},
#    'retweet_count': 1,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': True,
#   'quoted_status_id': 1188960493039509504,
#   'quoted_status_id_str': '1188960493039509504',
#   'quoted_status_permalink': {'url': 'https://t.co/CZqAOaN9hH',
#    'expanded': 'https://twitter.com/Penn_SACNAS/status/1188960493039509504',
#    'display': 'twitter.com/Penn_SACNAS/st…'},
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 29 00:22:55 +0000 2019',
#   'id': 1188974458192781313,
#   'id_str': '1188974458192781313',
#   'full_text': 'RT @ayoitsdixon: Yo leyendo a los del otro Twitter hablando mal de los del otro Twitter y diciendo que pertenecen a este Twitter https://t.…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'ayoitsdixon',
#      'name': 'áv',
#      'id': 1079166428027256834,
#      'id_str': '1079166428027256834',
#      'indices': [3, 15]}],
#    'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 283258277,
#    'id_str': '283258277',
#    'name': 'A r o l k a 🦋',
#    'screen_name': 'ArolkaMercado_',
#    'location': 'Santiago, República Dominicana',
#    'description': 'No tomes mis tuits de manera personal, sino, puedo caerte mal. 🍂',
#    'url': 'https://t.co/20Hl0Og4Ew',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/20Hl0Og4Ew',
#        'expanded_url': 'https://www.instagram.com/arolkamercado/',
#        'display_url': 'instagram.com/arolkamercado/',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1797,
#    'friends_count': 255,
#    'listed_count': 5,
#    'created_at': 'Sat Apr 16 22:57:01 +0000 2011',
#    'favourites_count': 25971,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 70227,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FF6699',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1183232525998661632/Vovb82x4_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183232525998661632/Vovb82x4_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/283258277/1536899492',
#    'profile_link_color': 'B40B43',
#    'profile_sidebar_border_color': 'CC3366',
#    'profile_sidebar_fill_color': 'E5507E',
#    'profile_text_color': '362720',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 29 00:00:02 +0000 2019',
#    'id': 1188968700323467265,
#    'id_str': '1188968700323467265',
#    'full_text': 'Yo leyendo a los del otro Twitter hablando mal de los del otro Twitter y diciendo que pertenecen a este Twitter https://t.co/G9tx8hapbz',
#    'truncated': False,
#    'display_text_range': [0, 111],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1188968676420182016,
#       'id_str': '1188968676420182016',
#       'indices': [112, 135],
#       'media_url': 'http://pbs.twimg.com/media/EIAQtjcXYAAbWt5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EIAQtjcXYAAbWt5.jpg',
#       'url': 'https://t.co/G9tx8hapbz',
#       'display_url': 'pic.twitter.com/G9tx8hapbz',
#       'expanded_url': 'https://twitter.com/ayoitsdixon/status/1188968700323467265/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 567, 'h': 566, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 567, 'h': 566, 'resize': 'fit'},
#        'small': {'w': 567, 'h': 566, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1188968676420182016,
#       'id_str': '1188968676420182016',
#       'indices': [112, 135],
#       'media_url': 'http://pbs.twimg.com/media/EIAQtjcXYAAbWt5.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EIAQtjcXYAAbWt5.jpg',
#       'url': 'https://t.co/G9tx8hapbz',
#       'display_url': 'pic.twitter.com/G9tx8hapbz',
#       'expanded_url': 'https://twitter.com/ayoitsdixon/status/1188968700323467265/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 567, 'h': 566, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 567, 'h': 566, 'resize': 'fit'},
#        'small': {'w': 567, 'h': 566, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1079166428027256834,
#     'id_str': '1079166428027256834',
#     'name': 'áv',
#     'screen_name': 'ayoitsdixon',
#     'location': '',
#     'description': 'el enemy de los guasíbiri',
#     'url': 'https://t.co/ozkTNjSU08',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ozkTNjSU08',
#         'expanded_url': 'http://xn--ida.com',
#         'display_url': 'ñ.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 297,
#     'friends_count': 118,
#     'listed_count': 2,
#     'created_at': 'Sun Dec 30 00:05:01 +0000 2018',
#     'favourites_count': 5540,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2984,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1187545367564443648/vBD0nFRe_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1187545367564443648/vBD0nFRe_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1079166428027256834/1554350989',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 6,
#    'favorite_count': 13,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': True,
#    'possibly_sensitive_appealable': False,
#    'lang': 'es'},
#   'is_quote_status': False,
#   'retweet_count': 6,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'es'},
#  {'created_at': 'Tue Oct 29 00:22:49 +0000 2019',
#   'id': 1188974434469732353,
#   'id_str': '1188974434469732353',
#   'full_text': 'YOO 🤣🤣 https://t.co/9jKLpLnpEf',
#   'truncated': False,
#   'display_text_range': [0, 6],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/9jKLpLnpEf',
#      'expanded_url': 'https://twitter.com/anny1395/status/1188973995640741888',
#      'display_url': 'twitter.com/anny1395/statu…',
#      'indices': [7, 30]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 283258277,
#    'id_str': '283258277',
#    'name': 'A r o l k a 🦋',
#    'screen_name': 'ArolkaMercado_',
#    'location': 'Santiago, República Dominicana',
#    'description': 'No tomes mis tuits de manera personal, sino, puedo caerte mal. 🍂',
#    'url': 'https://t.co/20Hl0Og4Ew',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/20Hl0Og4Ew',
#        'expanded_url': 'https://www.instagram.com/arolkamercado/',
#        'display_url': 'instagram.com/arolkamercado/',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1797,
#    'friends_count': 255,
#    'listed_count': 5,
#    'created_at': 'Sat Apr 16 22:57:01 +0000 2011',
#    'favourites_count': 25971,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 70227,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FF6699',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1183232525998661632/Vovb82x4_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183232525998661632/Vovb82x4_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/283258277/1536899492',
#    'profile_link_color': 'B40B43',
#    'profile_sidebar_border_color': 'CC3366',
#    'profile_sidebar_fill_color': 'E5507E',
#    'profile_text_color': '362720',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1188973995640741888,
#   'quoted_status_id_str': '1188973995640741888',
#   'quoted_status_permalink': {'url': 'https://t.co/9jKLpLnpEf',
#    'expanded': 'https://twitter.com/anny1395/status/1188973995640741888',
#    'display': 'twitter.com/anny1395/statu…'},
#   'quoted_status': {'created_at': 'Tue Oct 29 00:21:05 +0000 2019',
#    'id': 1188973995640741888,
#    'id_str': '1188973995640741888',
#    'full_text': 'A mi me ven tranquilita pero todo el día en mi mente esta sonando “no me conoces”.',
#    'truncated': False,
#    'display_text_range': [0, 82],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 627886915,
#     'id_str': '627886915',
#     'name': 'Rocío🍍',
#     'screen_name': 'Anny1395',
#     'location': 'Santiago, Dominican Republic',
#     'description': 'Winterfell 📌  #HALAMADRID',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 5728,
#     'friends_count': 5535,
#     'listed_count': 2,
#     'created_at': 'Fri Jul 06 00:38:23 +0000 2012',
#     'favourites_count': 8611,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 26810,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0A0A0A',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1186488209586479104/85czXMnt_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1186488209586479104/85czXMnt_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/627886915/1564790148',
#     'profile_link_color': '9266CC',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'und'},
#  {'created_at': 'Tue Oct 29 00:20:50 +0000 2019',
#   'id': 1188973931702571008,
#   'id_str': '1188973931702571008',
#   'full_text': 'RT @TheMobMuseum: Where did Americans get their liquor during Prohibition? Much of it came from our friends to the north. Attend this progr…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'TheMobMuseum',
#      'name': 'The Mob Museum',
#      'id': 55354357,
#      'id_str': '55354357',
#      'indices': [3, 16]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 36877779,
#    'id_str': '36877779',
#    'name': 'Vegas Sports ®',
#    'screen_name': 'VegasSports',
#    'location': 'Las Vegas, NV',
#    'description': 'Unbiased and impartial gambling notes from an experienced and successful prognosticator of sporting events. #VegasStrong #PrayForHongKong 😷 #FreeTibet',
#    'url': 'https://t.co/fBovruOmv9',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/fBovruOmv9',
#        'expanded_url': 'http://www.VegasSports.com',
#        'display_url': 'VegasSports.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 54984,
#    'friends_count': 48740,
#    'listed_count': 348,
#    'created_at': 'Fri May 01 04:02:36 +0000 2009',
#    'favourites_count': 6374,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 35169,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'ABB8C2',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/378800000408024914/c67b1e56cf23510d3462628cd43d0630_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/378800000408024914/c67b1e56cf23510d3462628cd43d0630_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/36877779/1471652354',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': 'CFD5D6',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 29 00:16:20 +0000 2019',
#    'id': 1188972799911759873,
#    'id_str': '1188972799911759873',
#    'full_text': "Where did Americans get their liquor during Prohibition? Much of it came from our friends to the north. Attend this program to learn how Canada’s underground booze operations flourished through partnerships w/ Chicago's Al Capone and Detroit’s Purple Gang. https://t.co/WYMzUU121B https://t.co/QwlmVsHBHR",
#    'truncated': False,
#    'display_text_range': [0, 280],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/WYMzUU121B',
#       'expanded_url': 'http://bit.ly/2NlCYT2',
#       'display_url': 'bit.ly/2NlCYT2',
#       'indices': [257, 280]}],
#     'media': [{'id': 1188972796405321728,
#       'id_str': '1188972796405321728',
#       'indices': [281, 304],
#       'media_url': 'http://pbs.twimg.com/media/EIAUdXlXkAAIHSH.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EIAUdXlXkAAIHSH.jpg',
#       'url': 'https://t.co/QwlmVsHBHR',
#       'display_url': 'pic.twitter.com/QwlmVsHBHR',
#       'expanded_url': 'https://twitter.com/TheMobMuseum/status/1188972799911759873/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1200, 'h': 628, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 356, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1188972796405321728,
#       'id_str': '1188972796405321728',
#       'indices': [281, 304],
#       'media_url': 'http://pbs.twimg.com/media/EIAUdXlXkAAIHSH.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EIAUdXlXkAAIHSH.jpg',
#       'url': 'https://t.co/QwlmVsHBHR',
#       'display_url': 'pic.twitter.com/QwlmVsHBHR',
#       'expanded_url': 'https://twitter.com/TheMobMuseum/status/1188972799911759873/photo/1',
#       'type': 'photo',
#       'sizes': {'large': {'w': 1200, 'h': 628, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 680, 'h': 356, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 628, 'resize': 'fit'}}}]},
#    'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 55354357,
#     'id_str': '55354357',
#     'name': 'The Mob Museum',
#     'screen_name': 'TheMobMuseum',
#     'location': 'Las Vegas - Downtown',
#     'description': 'Named one of the Best Places to Travel by Travel & Leisure Magazine and a Top 25 museum in the U.S. by TripAdvisor.',
#     'url': 'https://t.co/kcDryS7Rk1',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/kcDryS7Rk1',
#         'expanded_url': 'http://themobmuseum.org/',
#         'display_url': 'themobmuseum.org',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 18491,
#     'friends_count': 2404,
#     'listed_count': 326,
#     'created_at': 'Thu Jul 09 20:37:43 +0000 2009',
#     'favourites_count': 5236,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 7630,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/978729471518810112/9rFW5aHX_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/978729471518810112/9rFW5aHX_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/55354357/1499903332',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 5,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 29 00:20:42 +0000 2019',
#   'id': 1188973898605289472,
#   'id_str': '1188973898605289472',
#   'full_text': "You know all those weird AF ~sexy~ Halloween costumes? Well, here's what they *really* look like IRL. Not gonna lie, the sexy Taco Bell salsa packet is pretty cute. (Via @Cosmopolitan) https://t.co/ZasbPwf5qZ",
#   'truncated': False,
#   'display_text_range': [0, 184],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Cosmopolitan',
#      'name': 'Cosmopolitan',
#      'id': 23482952,
#      'id_str': '23482952',
#      'indices': [170, 183]}],
#    'urls': [],
#    'media': [{'id': 1188972499989454848,
#      'id_str': '1188972499989454848',
#      'indices': [185, 208],
#      'media_url': 'http://pbs.twimg.com/media/EIAVdJRUcAAYScg.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EIAVdJRUcAAYScg.jpg',
#      'url': 'https://t.co/ZasbPwf5qZ',
#      'display_url': 'pic.twitter.com/ZasbPwf5qZ',
#      'expanded_url': 'https://twitter.com/seventeen/status/1188973898605289472/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1188972499989454848,
#      'id_str': '1188972499989454848',
#      'indices': [185, 208],
#      'media_url': 'http://pbs.twimg.com/media/EIAVdJRUcAAYScg.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EIAVdJRUcAAYScg.jpg',
#      'url': 'https://t.co/ZasbPwf5qZ',
#      'display_url': 'pic.twitter.com/ZasbPwf5qZ',
#      'expanded_url': 'https://twitter.com/seventeen/status/1188973898605289472/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [1, 1],
#       'duration_millis': 375501,
#       'variants': [{'bitrate': 432000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1188972499989454848/vid/320x320/eFbZfGLXOQvpllpx.mp4?tag=13'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1188972499989454848/pl/OTi4vJ6cq6PHRgCa.m3u8?tag=13'},
#        {'bitrate': 1280000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1188972499989454848/vid/720x720/GjLsZV-MA9eBFxRR.mp4?tag=13'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1188972499989454848/vid/480x480/JA8382XhJkn-Ec02.mp4?tag=13'}]},
#      'additional_media_info': {'title': 'E4 What “Sexy” Halloween Costumes *Actually* Look Like on 5 Women\n',
#       'description': 'Powered by SnappyTV',
#       'call_to_actions': {'visit_site': {'url': 'http://www.seventeen.com/'}},
#       'embeddable': True,
#       'monetizable': False}}]},
#   'source': '<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 16824090,
#    'id_str': '16824090',
#    'name': 'Seventeen',
#    'screen_name': 'seventeen',
#    'location': 'New York, NY',
#    'description': 'The ~totally official~ Seventeen Twitter! Follow us on Snapchat: seventeenmag Shop our new fashion line at https://t.co/CVKJGTRFSP',
#    'url': 'http://t.co/AmLyj3OEZV',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/AmLyj3OEZV',
#        'expanded_url': 'http://www.seventeen.com',
#        'display_url': 'seventeen.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': [{'url': 'https://t.co/CVKJGTRFSP',
#        'expanded_url': 'http://editby17.com',
#        'display_url': 'editby17.com',
#        'indices': [107, 130]}]}},
#    'protected': False,
#    'followers_count': 1342185,
#    'friends_count': 2604,
#    'listed_count': 3977,
#    'created_at': 'Fri Oct 17 12:58:21 +0000 2008',
#    'favourites_count': 5112,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 120803,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1082708158466981888/Pu38hNkm_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082708158466981888/Pu38hNkm_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16824090/1523991150',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 29 00:20:35 +0000 2019',
#   'id': 1188973869513760770,
#   'id_str': '1188973869513760770',
#   'full_text': 'Why do ppl even take Aquarius men serious?  You knew they was a hoe before you wanted a taste',
#   'truncated': False,
#   'display_text_range': [0, 93],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 878697981884727297,
#    'id_str': '878697981884727297',
#    'name': 'AQUARIUS TRAPHOUSE',
#    'screen_name': 'aquarina',
#    'location': '',
#    'description': 'real nigga astrology for Aquarius ONLY',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 49715,
#    'friends_count': 0,
#    'listed_count': 88,
#    'created_at': 'Sat Jun 24 19:34:59 +0000 2017',
#    'favourites_count': 225,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 8387,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1180827347945246721/jNte3hwD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1180827347945246721/jNte3hwD_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/878697981884727297/1570276174',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 6,
#   'favorite_count': 32,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 29 00:20:15 +0000 2019',
#   'id': 1188973787284430849,
#   'id_str': '1188973787284430849',
#   'full_text': 'RT @hector201192: Se me dioooooo . Ignacio es good peopleee https://t.co/yY0CLVquQi',
#   'truncated': False,
#   'display_text_range': [0, 83],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'hector201192',
#      'name': 'Hector e. serra latorre',
#      'id': 444144204,
#      'id_str': '444144204',
#      'indices': [3, 16]}],
#    'urls': [{'url': 'https://t.co/yY0CLVquQi',
#      'expanded_url': 'https://twitter.com/nestorduprey/status/1188933380211200000',
#      'display_url': 'twitter.com/nestorduprey/s…',
#      'indices': [60, 83]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 272627216,
#    'id_str': '272627216',
#    'name': 'Johana Martinez Rosario',
#    'screen_name': 'JohanaMRPhD',
#    'location': 'Puerto Rico',
#    'description': 'Psicóloga académica-investigativa. Mujer de proyectos. Obsidis Consortia, #BSidesPR, PRBloggerCon. Comunitaria, humana, leal y ética, Derecho Civil y Humano',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1745,
#    'friends_count': 948,
#    'listed_count': 62,
#    'created_at': 'Sat Mar 26 21:25:39 +0000 2011',
#    'favourites_count': 7322,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 79473,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'FFF04D',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1181949747688554496/W14FUtmG_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1181949747688554496/W14FUtmG_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/272627216/1570633755',
#    'profile_link_color': '0099CC',
#    'profile_sidebar_border_color': 'FFF8AD',
#    'profile_sidebar_fill_color': 'F6FFD1',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon Oct 28 21:46:49 +0000 2019',
#    'id': 1188935172118503424,
#    'id_str': '1188935172118503424',
#    'full_text': 'Se me dioooooo . Ignacio es good peopleee https://t.co/yY0CLVquQi',
#    'truncated': False,
#    'display_text_range': [0, 41],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/yY0CLVquQi',
#       'expanded_url': 'https://twitter.com/nestorduprey/status/1188933380211200000',
#       'display_url': 'twitter.com/nestorduprey/s…',
#       'indices': [42, 65]}]},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 444144204,
#     'id_str': '444144204',
#     'name': 'Hector e. serra latorre',
#     'screen_name': 'hector201192',
#     'location': 'caguas ',
#     'description': 'plomeria refrigeración  . trabajo de soldadura . inventamos lo q sea .pregunton me gusta solucionar problemas .sigueme si eres inteligente tel 787 692 6355',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 889,
#     'friends_count': 3182,
#     'listed_count': 8,
#     'created_at': 'Thu Dec 22 23:18:50 +0000 2011',
#     'favourites_count': 46249,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 41396,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1125533392446140417/-jmYV8Dr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1125533392446140417/-jmYV8Dr_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': True,
#    'quoted_status_id': 1188933380211200000,
#    'quoted_status_id_str': '1188933380211200000',
#    'quoted_status_permalink': {'url': 'https://t.co/yY0CLVquQi',
#     'expanded': 'https://twitter.com/nestorduprey/status/1188933380211200000',
#     'display': 'twitter.com/nestorduprey/s…'},
#    'quoted_status': {'created_at': 'Mon Oct 28 21:39:41 +0000 2019',
#     'id': 1188933380211200000,
#     'id_str': '1188933380211200000',
#     'full_text': 'El momento en que Ignacio firma su endoso a \u2066@VictoriaPorPR\u2069 hoy lunes 28 de octubre. Para que lo carpeteen bien. #yoendoseelcambio https://t.co/kmsmLYcK2X',
#     'truncated': False,
#     'display_text_range': [0, 131],
#     'entities': {'hashtags': [{'text': 'yoendoseelcambio',
#        'indices': [114, 131]}],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'VictoriaPorPR',
#        'name': 'Victoria Ciudadana',
#        'id': 1097956549652332544,
#        'id_str': '1097956549652332544',
#        'indices': [45, 59]}],
#      'urls': [],
#      'media': [{'id': 1188933373500280832,
#        'id_str': '1188933373500280832',
#        'indices': [132, 155],
#        'media_url': 'http://pbs.twimg.com/media/EH_wmp0XUAAFFvo.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/EH_wmp0XUAAFFvo.jpg',
#        'url': 'https://t.co/kmsmLYcK2X',
#        'display_url': 'pic.twitter.com/kmsmLYcK2X',
#        'expanded_url': 'https://twitter.com/nestorduprey/status/1188933380211200000/photo/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 510, 'h': 680, 'resize': 'fit'},
#         'large': {'w': 1200, 'h': 1600, 'resize': 'fit'},
#         'medium': {'w': 900, 'h': 1200, 'resize': 'fit'}}}]},
#     'extended_entities': {'media': [{'id': 1188933373500280832,
#        'id_str': '1188933373500280832',
#        'indices': [132, 155],
# ...
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1106214730958548992/OoWgeZ2d_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1106214730958548992/OoWgeZ2d_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/372758243/1506606285',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 59,
#   'favorite_count': 178,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': True,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'},
#  {'created_at': 'Tue Oct 29 00:07:12 +0000 2019',
#   'id': 1188970503094059008,
#   'id_str': '1188970503094059008',
#   'full_text': 'Me descubrieron https://t.co/xwqmJ87t98',
#   'truncated': False,
#   'display_text_range': [0, 15],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/xwqmJ87t98',
#      'expanded_url': 'https://twitter.com/elvishhhhhh/status/1188968973074874368',
#      'display_url': 'twitter.com/elvishhhhhh/st…',
#      'indices': [16, 39]}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 770729175082602496,
#    'id_str': '770729175082602496',
#    'name': 'Andrea Rivera',
#    'screen_name': 'andreanataliarr',
#    'location': 'Isla Meme',
#    'description': 'UPRRP • 21 • cell and molecular bio undergrad • medical humanities minor • women & gender studies minor',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 905,
#    'friends_count': 607,
#    'listed_count': 17,
#    'created_at': 'Tue Aug 30 21:05:29 +0000 2016',
#    'favourites_count': 34009,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 28393,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1157666904154279936/cHFaJl3b_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1157666904154279936/cHFaJl3b_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/770729175082602496/1560186844',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1188968973074874368,
#   'quoted_status_id_str': '1188968973074874368',
#   'quoted_status_permalink': {'url': 'https://t.co/xwqmJ87t98',
#    'expanded': 'https://twitter.com/elvishhhhhh/status/1188968973074874368',
#    'display': 'twitter.com/elvishhhhhh/st…'},
#   'quoted_status': {'created_at': 'Tue Oct 29 00:01:07 +0000 2019',
#    'id': 1188968973074874368,
#    'id_str': '1188968973074874368',
#    'full_text': 'si vives en una urbanización de acceso controlado, te vas en la revolución',
#    'truncated': False,
#    'display_text_range': [0, 74],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 273257891,
#     'id_str': '273257891',
#     'name': '𝔖𝔭𝔬𝔬𝔨𝔶 𝔣𝔢𝔪 𝔳𝔢𝔯𝔰',
#     'screen_name': 'elvishhhhhh',
#     'location': 'Beach City',
#     'description': 'pisces, pokémon trainer and pop enthusiast UPRRP | I live my life one hyperfixation at a time',
#     'url': 'https://t.co/uoIW6RZbbF',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/uoIW6RZbbF',
#         'expanded_url': 'https://curiouscat.me/eob32elvis',
#         'display_url': 'curiouscat.me/eob32elvis',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1014,
#     'friends_count': 622,
#     'listed_count': 9,
#     'created_at': 'Mon Mar 28 04:06:43 +0000 2011',
#     'favourites_count': 40830,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 20381,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '0099B9',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1188818351621115905/I-2kApHy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1188818351621115905/I-2kApHy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/273257891/1569903084',
#     'profile_link_color': '0099B9',
#     'profile_sidebar_border_color': '5ED4DC',
#     'profile_sidebar_fill_color': '95E8EC',
#     'profile_text_color': '3C3940',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'es'},
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'es'},
#  {'created_at': 'Tue Oct 29 00:07:06 +0000 2019',
#   'id': 1188970478796443649,
#   'id_str': '1188970478796443649',
#   'full_text': 'RT @Zendaya: Lancôme L’absolu Rouge campaign outtake♥️ https://t.co/lWmL8CeG6l',
#   'truncated': False,
#   'display_text_range': [0, 78],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'Zendaya',
#      'name': 'Zendaya',
#      'id': 154280902,
#      'id_str': '154280902',
#      'indices': [3, 11]}],
#    'urls': [],
#    'media': [{'id': 1188969075621261318,
#      'id_str': '1188969075621261318',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#      'url': 'https://t.co/lWmL8CeG6l',
#      'display_url': 'pic.twitter.com/lWmL8CeG6l',
#      'expanded_url': 'https://twitter.com/Zendaya/status/1188969082843889664/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 569, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1004, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 1714, 'h': 2048, 'resize': 'fit'}},
#      'source_status_id': 1188969082843889664,
#      'source_status_id_str': '1188969082843889664',
#      'source_user_id': 154280902,
#      'source_user_id_str': '154280902'}]},
#   'extended_entities': {'media': [{'id': 1188969075621261318,
#      'id_str': '1188969075621261318',
#      'indices': [55, 78],
#      'media_url': 'http://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#      'url': 'https://t.co/lWmL8CeG6l',
#      'display_url': 'pic.twitter.com/lWmL8CeG6l',
#      'expanded_url': 'https://twitter.com/Zendaya/status/1188969082843889664/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 569, 'h': 680, 'resize': 'fit'},
#       'medium': {'w': 1004, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 1714, 'h': 2048, 'resize': 'fit'}},
#      'source_status_id': 1188969082843889664,
#      'source_status_id_str': '1188969082843889664',
#      'source_user_id': 154280902,
#      'source_user_id_str': '154280902'}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1102392403,
#    'id_str': '1102392403',
#    'name': 'viviana',
#    'screen_name': 'vvjmv',
#    'location': 'iupi',
#    'description': 'ya basic',
#    'url': 'https://t.co/8X1iudpDQC',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/8X1iudpDQC',
#        'expanded_url': 'https://Instagram.com/vivianadej/',
#        'display_url': 'Instagram.com/vivianadej/',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 430,
#    'friends_count': 244,
#    'listed_count': 2,
#    'created_at': 'Sat Jan 19 00:28:57 +0000 2013',
#    'favourites_count': 11753,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 40313,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1174339726343643139/rDZt9D7q_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1174339726343643139/rDZt9D7q_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1102392403/1568819625',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': True,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue Oct 29 00:01:33 +0000 2019',
#    'id': 1188969082843889664,
#    'id_str': '1188969082843889664',
#    'full_text': 'Lancôme L’absolu Rouge campaign outtake♥️ https://t.co/lWmL8CeG6l',
#    'truncated': False,
#    'display_text_range': [0, 41],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1188969075621261318,
#       'id_str': '1188969075621261318',
#       'indices': [42, 65],
#       'media_url': 'http://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#       'url': 'https://t.co/lWmL8CeG6l',
#       'display_url': 'pic.twitter.com/lWmL8CeG6l',
#       'expanded_url': 'https://twitter.com/Zendaya/status/1188969082843889664/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 569, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 1004, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1714, 'h': 2048, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1188969075621261318,
#       'id_str': '1188969075621261318',
#       'indices': [42, 65],
#       'media_url': 'http://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EIAREylUcAYiVhV.jpg',
#       'url': 'https://t.co/lWmL8CeG6l',
#       'display_url': 'pic.twitter.com/lWmL8CeG6l',
#       'expanded_url': 'https://twitter.com/Zendaya/status/1188969082843889664/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 569, 'h': 680, 'resize': 'fit'},
#        'medium': {'w': 1004, 'h': 1200, 'resize': 'fit'},
#        'large': {'w': 1714, 'h': 2048, 'resize': 'fit'}}}]},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 154280902,
#     'id_str': '154280902',
#     'name': 'Zendaya',
#     'screen_name': 'Zendaya',
#     'location': '',
#     'description': 'Euphoria on @hbo Sundays @ 10pm #AllForUs',
#     'url': 'https://t.co/pFXD2z7dZ3',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/pFXD2z7dZ3',
#         'expanded_url': 'https://euphoria.lnk.to/AllForUs',
#         'display_url': 'euphoria.lnk.to/AllForUs',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 16810209,
#     'friends_count': 1771,
#     'listed_count': 16165,
#     'created_at': 'Thu Jun 10 21:08:45 +0000 2010',
#     'favourites_count': 30616,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 58738,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '181818',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1050072866023194626/U82dxbhR_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1050072866023194626/U82dxbhR_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/154280902/1568127556',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F6F6F6',
#     'profile_text_color': '0D0414',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'regular'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 6276,
#    'favorite_count': 36016,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'possibly_sensitive_appealable': False,
#    'lang': 'fr'},
#   'is_quote_status': False,
#   'retweet_count': 6276,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'fr'}]

# %%
tweets2 = Tweets("halloween",20)

# %%
tweets2.countTweets()
# Out:
# 20

# %%
working
# Out:
# ['1083533',
#  '1413684',
#  '1845868',
#  '2255383',
#  '2399451',
#  '444458',
#  '455546',
#  '465303',
#  '5453097',
#  '5731785',
#  '7534996',
#  '9256359',
#  '9302451',
#  '9600819',
#  '9808258']

# %% [markdown]
# *END CUT*
#
# ---

# %% [markdown]
# # EXERCISE 2.3: Reflection on coding
#
# Open coding can often be an iterative process. When we first start out, we don't really know what we're looking for. As a result, the first few items annotated might only get a few codes, and we might miss ideas that we don't initially think are important. As we see more and more items, our ideas of what needs to be annotated will change, and we'll start adding in codes that might also apply to earlier messages. Thus, we often need to review and re-annotate earlier tweets to account for changes in our interpreations.
#
# Review your annotations the tweets that you reviewed. Revise the codes associated with these tweets, adding items from the overall list of codes as appropriate. Describe the change that you have made.

# %% [markdown]
# ---
# *ANSWER FOLLOWS - insert here*

# %% [markdown]
# *END CUT*
#
# ---

# %% [markdown]
# # EXERCISE 2.4: Reflection on storage/serialization
#
# In working with this small set of 100 tweets, we are taking a very simple approach to storage and management of the tweets and annotations. Storing everything in a nested Python dictionary and then dumping it to disk as JSON text can be very appealing. What are the strengths and weaknesses of this approach, and how might these strengths and weaknesses differ with larger datasets containing 100,000 or 100 million datasets? What alternative  strategies might you use for larger datasets?

# %% [markdown]
# ---
# *ANSWER FOLLOWS - insert here*

# %% [markdown]
# *END CUT*
#
# ---

# %% [markdown]
# # 2.2 Final Notes
#
# [Part 3](SocialMedia%20-%20Part%203.ipynb) will explore the application of Natural Language Processing  - NLP - techniques to Tweet data.
